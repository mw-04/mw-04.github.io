# %% [markdown]
# <a href="https://colab.research.google.com/github/mw-04/mw-04.github.io/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
url_2024 = "https://bcdanl.github.io/data/esg_proj_2024_data.csv"
esg_proj_2024_data = pd.read_csv(url_2024)

url = "https://bcdanl.github.io/data/stock_history_2023.csv"
stock_history_2023 = pd.read_csv(url)

# %%
sns.histplot(data = esg_proj_2024_data,
             x = 'Total_ESG',
             bins = 10)
# Out:
# <Axes: xlabel='Total_ESG', ylabel='Count'>

# %%
sns.histplot(data = esg_proj_2024_data,
             x = 'Environmental',
             bins = 10)
# Out:
# <Axes: xlabel='Environmental', ylabel='Count'>

# %%
sns.histplot(data = esg_proj_2024_data,
             x = 'Social',
             bins = 10)
# Out:
# <Axes: xlabel='Social', ylabel='Count'>

# %%
sns.histplot(data = esg_proj_2024_data,
             x = 'Governance',
             bins = 10)
# Out:
# <Axes: xlabel='Governance', ylabel='Count'>
